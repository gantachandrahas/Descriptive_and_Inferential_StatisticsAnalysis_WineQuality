# %% [markdown]
#                                                ### PROJECT-2 ###

# %%
import pandas as pd
import numpy as np

# %%
# 1.Display the data of white wine and red wine

# %%
df_white=pd.read_csv(r'C:\Users\ganta\Downloads\winequality-white.csv')

# %%
df_white
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red=pd.read_csv(r'C:\Users\ganta\Downloads\winequality-red.csv')

# %%
df_red
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# 2.Get the size of both white wine and red wine.

print("white wine:",df_white.shape)
print("red wine: " ,df_red.shape)
# Out:
# white wine: (4898, 12)
# red wine:  (1599, 12)

# %%
# 3.Get the number of null in both type of wines

df_white.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_red.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# 4.Check for duplicates and remove them in both type of wine data

# %%
df_white.duplicated().sum()
# Out:
# 937

# %%
df_white.drop_duplicates(inplace=True)

# %%
df_white.duplicated().sum()
# Out:
# 0

# %%
df_red.duplicated().sum()
# Out:
# 240

# %%
df_red.drop_duplicates(inplace=True)

# %%
df_red.duplicated().sum()
# Out:
# 0

# %%
# 5.Get the number of uniques values in all Feature and print them

# %%
df_white.nunique()
# Out:
# fixed_acidity            68
# volatile_acidity        125
# citric_acid              87
# residual_sugar          310
# chlorides               160
# free_sulfur_dioxide     132
# total_sulfur_dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
df_red.nunique()
# Out:
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur_dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# 6.Print the mean density of both the sets

white_mean=df_white.density.mean()
white_mean
# Out:
# 0.9937895304216049

# %%
red_mean=df_red.density.mean()
red_mean
# Out:
# 0.9967089477557026

# %%
# 7.Combine both the datasets with color of the wine in column
color_white = np.repeat('white', df_white.shape[0])
color_red = np.repeat('red', df_red.shape[0])

# %%
df_white['color']=color_white
df_white.tail()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# ...

# %%
df_red['color']=color_red
df_red.tail()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality color
# ...

# %%
color_wine=df_red.append(df_white)
color_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# 8.Remove the null values if any
df_white.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df_red.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
## 9.Remove the outliers if any


def find_outliers_IQR(color_wine):
    q1=color_wine.quantile(0.25)
    q3=color_wine.quantile(0.75)
    IQR=q3-q1
    outliers=color_wine[((color_wine<(q1-1.5*IQR)) | (color_wine>(q3+1.5*IQR)))]
    return outliers

outliers = find_outliers_IQR(color_wine[["fixed_acidity","volatile_acidity","citric_acid","residual_sugar","chlorides","free_sulfur_dioxide","total_sulfur_dioxide","density","pH","sulphates","alcohol","quality"]])

print("number of outliers: "+ str(len(outliers)))
print()
print("max outlier value: "+ str(outliers.max()))
print()
print("min outlier value: "+ str(outliers.min()))
# Out:
# number of outliers: 5320
#
# max outlier value: fixed_acidity            15.90000
# volatile_acidity          1.58000
# citric_acid               1.66000
# residual_sugar           65.80000
# chlorides                 0.61100
# free_sulfur_dioxide     289.00000
# total_sulfur_dioxide    440.00000
# density                   1.03898
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   9.00000
# dtype: float64
#
# min outlier value: fixed_acidity             3.80000
# volatile_acidity          0.68000
# citric_acid               0.65000
# residual_sugar           16.10000
# chlorides                 0.10900
# free_sulfur_dioxide      79.00000
# total_sulfur_dioxide    278.00000
# density                   1.00369
# pH                        2.72000
# sulphates                 0.86000
# alcohol                  14.90000
# quality                   3.00000
# dtype: float64

# %%
# 10. Do wines with higher alcohol content receive better ratings?
color_wine.alcohol.median()
# Out:
# 10.4

# %%
low_alcohol=color_wine[color_wine.alcohol < 10.3]
high_alcohol=color_wine[color_wine.alcohol >= 10.3]
num_samples=color_wine.shape[0]
num_samples==low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
low_alcohol.quality.mean()
# Out:
# 5.428057553956834

# %%
high_alcohol.quality.mean()
# Out:
# 6.122072391767211

# %%
# 11.Find correlation between citric acid content and PH.       
color_wine1=color_wine.groupby(by=['citric_acid'],as_index=False)['pH'].mean()
color_wine1
# Out:
#     citric_acid        pH
# 0          0.00  3.443824
# 1          0.01  3.395484
# 2          0.02  3.419318
# 3          0.03  3.416154
# 4          0.04  3.368235
# ..          ...       ...
# 84         0.91  3.390000
# 85         0.99  3.090000
# 86         1.00  3.070000
# 87         1.23  3.030000
# 88         1.66  3.260000
#
# [89 rows x 2 columns]

# %%
color_wine.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.214752     0.330328
# volatile_acidity           0.214752          1.000000    -0.384192
# citric_acid                0.330328         -0.384192     1.000000
# residual_sugar            -0.104439         -0.163696     0.146189
# chlorides                  0.288918          0.367626     0.055199
# free_sulfur_dioxide       -0.281590         -0.349039     0.130849
# total_sulfur_dioxide      -0.327471         -0.400716     0.194835
# density                    0.478180          0.308452     0.094758
# pH                        -0.271182          0.246687    -0.344735
# sulphates                  0.304844          0.227772     0.059183
# alcohol                   -0.102573         -0.065411    -0.005496
# quality                   -0.080092         -0.265205     0.097954
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
color_wine1.corr()
# Out:
#              citric_acid        pH
# citric_acid     1.000000 -0.725151
# pH             -0.725151  1.000000

# %%
# 12.Find regression of PH on citric acid
x=color_wine.pH.values
x
# Out:
# array([3.51, 3.2 , 3.26, ..., 2.99, 3.34, 3.26])

# %%
y=color_wine.citric_acid.values
y
# Out:
# array([0.  , 0.  , 0.04, ..., 0.19, 0.3 , 0.38])

# %%
import matplotlib.pyplot as plt
from scipy import stats

slope, intercept, r, p, std_err = stats.linregress(x, y)

def regression(x):
    return slope * x + intercept

mymodel = list(map(regression, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
# 13.Find how many variables are independent.

# %%
a=df_white.iloc[:,1:11].values
a
# Out:
# array([[ 0.27,  0.36, 20.7 , ...,  3.  ,  0.45,  8.8 ],
#        [ 0.3 ,  0.34,  1.6 , ...,  3.3 ,  0.49,  9.5 ],
#        [ 0.28,  0.4 ,  6.9 , ...,  3.26,  0.44, 10.1 ],
#        ...,
#        [ 0.24,  0.19,  1.2 , ...,  2.99,  0.46,  9.4 ],
#        [ 0.29,  0.3 ,  1.1 , ...,  3.34,  0.38, 12.8 ],
#        [ 0.21,  0.38,  0.8 , ...,  3.26,  0.32, 11.8 ]])

# %%
b=df_red.iloc[:,1:11].values
b
# Out:
# array([[ 0.7  ,  0.   ,  1.9  , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 0.88 ,  0.   ,  2.6  , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 0.76 ,  0.04 ,  2.3  , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 0.55 ,  0.1  ,  2.2  , ...,  3.52 ,  0.76 , 11.2  ],
#        [ 0.645,  0.12 ,  2.   , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 0.31 ,  0.47 ,  3.6  , ...,  3.39 ,  0.66 , 11.   ]])

# %%
# 14.Create a new column as the acidity level. Divide the existing data into 5 groups based on the acidity level. 
# The levels are to be named ['High', 'Moderately_High', 'Medium', 'Low']. Acidity may be obtained from the PH.
groups=[2.72 ,3.11 ,3.21 ,3.32 ,4.01 ]
names = ['High', 'Moderately_High', 'Medium', 'Low']

color_wine['acidity_levels'] = pd.cut(color_wine['pH'],groups, labels=names)
color_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# 15.Find the mean quality of each acidity level with groupby. Use groupby
color_wine2=color_wine.groupby(by='quality').mean()
color_wine2
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.304369          0.462379     0.271505        4.034951
# 5             7.333248          0.393970     0.305845        5.481906
# 6             7.169027          0.315626     0.324671        5.153142
# 7             7.122021          0.292342     0.336040        4.171320
# 8             6.820270          0.302973     0.340541        4.771622
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060510            20.332524            101.516990  0.994802
# 5         0.066039            29.797660            119.572203  0.995734
# 6         0.054366            30.777873            114.433491  0.994377
# ...

# %%
# 16.Is a certain type of wine (red or white) associated with higher quality?
color_wine.groupby('color').mean().quality
# Out:
# color
# red      5.623252
# white    5.854835
# Name: quality, dtype: float64

# %%
# 17.Select samples with alcohol content less than the median
color_wine.alcohol.median()
# Out:
# 10.4

# %%
low_alcohol=color_wine[color_wine.alcohol < 10.4]
low_alcohol
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 5               7.4             0.660         0.00            1.80      0.075
# ...             ...               ...          ...             ...        ...
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4892            6.5             0.230         0.38            1.30      0.032
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
#
# ...

# %%
high_alcohol=color_wine[color_wine.alcohol >= 10.4]
high_alcohol
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 9               7.5             0.500         0.36             6.1      0.071
# 16              8.5             0.280         0.56             1.8      0.092
# 31              6.9             0.685         0.00             2.5      0.105
# 36              7.8             0.600         0.14             2.4      0.086
# 39              7.3             0.450         0.36             5.9      0.074
# ...             ...               ...          ...             ...        ...
# 4890            6.1             0.340         0.29             2.2      0.036
# 4891            5.7             0.210         0.32             0.9      0.038
# 4893            6.2             0.210         0.29             1.6      0.039
# 4896            5.5             0.290         0.30             1.1      0.022
# 4897            6.0             0.210         0.38             0.8      0.020
#
# ...

# %%
# 18.Get the quality rating for the low alcohol and high alcohol groups.

low_alcohol.quality.mean()
# Out:
# 5.439202148062908

# %%
high_alcohol.quality.mean()
# Out:
# 6.138223368964246

# %%
# 19.Do sweeter wines get more ratings?
color_wine.residual_sugar.median()
# Out:
# 2.7

# %%
low_sugar=color_wine[color_wine.residual_sugar < 2.7]
low_sugar
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 4892            6.5              0.23         0.38             1.3      0.032
# 4893            6.2              0.21         0.29             1.6      0.039
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
high_sugar=color_wine[color_wine.residual_sugar > 2.7]
high_sugar
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 9               7.5             0.500         0.36            6.10      0.071
# 14              8.9             0.620         0.18            3.80      0.176
# 15              8.9             0.620         0.19            3.90      0.170
# 18              7.4             0.590         0.08            4.40      0.086
# 33              6.9             0.605         0.12           10.70      0.073
# ...             ...               ...          ...             ...        ...
# 4884            6.5             0.330         0.38            8.30      0.048
# 4885            6.6             0.340         0.40            8.10      0.046
# 4886            6.2             0.210         0.28            5.70      0.028
# 4889            4.9             0.235         0.27           11.75      0.030
# 4894            6.6             0.320         0.36            8.00      0.047
#
# ...

# %%
low_sugar.quality.mean()
# Out:
# 5.78316032295271

# %%
high_sugar.quality.mean()
# Out:
# 5.80188679245283

# %%
# 20.Get the number of counts based on ratings and color of wine.
color_wine.groupby('color').quality.sum()
# Out:
# color
# red       7642
# white    23191
# Name: quality, dtype: int64

# %%
# 21.Is the density of red wine and white wine similar?
color_wine.groupby('color').density.mean()
# Out:
# color
# red      0.996709
# white    0.993790
# Name: density, dtype: float64

# %%
# 22.Is the confidence interval for the differences of the proportion of white wine with rating 3 and 
# the proportion of red wine with rating 3.
